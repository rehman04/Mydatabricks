# %% [markdown]
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning">
# </div>

# %% [markdown]
# # Using the Databricks CLI
# In this lesson, you will execute commands using the Databricks CLI. We will use the cluster web terminal for this demo.
#
# By the end of this lab, you should be able to:
# * Launch the driver's web terminal to run shell commands on the driver node
# * Install the Databricks CLI and configure authentication to a Databricks workspace
# * List files or clusters in your workspace to verify successful authentication
# * Configure Databricks Secrets

# %% [markdown]
# ## Setup
# Run the classroom setup script in the next cell to configure the classroom.

# %%
# %run ./Includes/Classroom-Setup-06.2

# %% [markdown]
# ## Install CLI
#
# Install the Databricks CLI using the following cell. Note that this procedure removes any existing version that may already be installed, and installs the newest version of the [Databricks CLI](https://docs.databricks.com/en/dev-tools/cli/index.html). A legacy version exists that is distributed through **`pip`**, however we recommend following the procedure here to install the newer one.

# %%
# %sh rm -f $(which databricks); curl -fsSL https://raw.githubusercontent.com/databricks/setup-cli/v0.211.0/install.sh | sh

# %% [markdown]
# ## Authentication
#
# Usually, you would have to set up authentication for the CLI. But in this training environment, that's already taken care of if you ran through the accompanying *Generate Tokens* notebook. If you did, credentials will already be loaded into the **`DATABRICKS_HOST`** and **`DATABRICKS_TOKEN`** environment variables. If you did not, run through it now then restart this notebook.

# %% [markdown]
# ## Using the CLI
#
# The cell below illustrates simple CLI usage. This displays a lists the contents of in */Users* workspace directory.

# %%
# %sh databricks workspace list /Users

# %% [markdown]
# The CLI provides access to a broad swath of Databricks functionality. Use the **`help`** command to access the online help.

# %%
# %sh databricks help

# %% [markdown]
# &copy; 2024 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the
# <a href="https://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/><a href="https://databricks.com/privacy-policy">Privacy Policy</a> |
# <a href="https://databricks.com/terms-of-use">Terms of Use</a> |
# <a href="https://help.databricks.com/">Support</a>
