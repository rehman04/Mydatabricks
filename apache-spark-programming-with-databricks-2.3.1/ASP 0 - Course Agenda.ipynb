# %% [markdown]
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning">
# </div>

# %% [markdown]
# # Apache Spark Programming with Databricks
# ## Course Agenda
#
# Taught over 4 half-days or 2 full-days.

# %% [markdown]
# # Day 1
# ## Introductions
# * [ASP 1.1 - Databricks Platform]($./ASP 1 - Introductions/ASP 1.1 - Databricks Platform)
# * [ASP 1.1L - Explore Datasets Lab]($./ASP 1 - Introductions/ASP 1.1L - Explore Datasets Lab)
#
#
# ## Spark Core
# * [ASP 2.1 - Spark SQL]($./ASP 2 - Spark Core/ASP 2.1 - Spark SQL)
# * [ASP 2.1L - Spark SQL Lab]($./ASP 2 - Spark Core/ASP 2.1L - Spark SQL Lab)
# * [ASP 2.2 - Reader & Writer]($./ASP 2 - Spark Core/ASP 2.2 - Reader & Writer)
# * [ASP 2.2L - Ingesting Data Lab]($./ASP 2 - Spark Core/ASP 2.2L - Ingesting Data Lab)
# * [ASP 2.3 - DataFrame & Column]($./ASP 2 - Spark Core/ASP 2.3 - DataFrame & Column)

# %% [markdown]
# # Day 2
#
# ## Spark Core (Continued)
# * [ASP 2.3L - Purchase Revenues Lab]($./ASP 2 - Spark Core/ASP 2.3L - Purchase Revenues Lab)
#
# ## Functions
# * [ASP 3.1 - Aggregation]($./ASP 3 - Functions/ASP 3.1 - Aggregation)
# * [ASP 3.1L - Revenue by Traffic Lab]($./ASP 3 - Functions/ASP 3.1L - Revenue by Traffic Lab)
# * [ASP 3.2 - Datetimes]($./ASP 3 - Functions/ASP 3.2 - Datetimes)
# * [ASP 3.2L - Active Users Lab]($./ASP 3 - Functions/ASP 3.2L - Active Users Lab)
# * [ASP 3.3 - Complex Types]($./ASP 3 - Functions/ASP 3.3 - Complex Types)
# * [ASP 3.3L - Users]($./ASP 3 - Functions/ASP 3.3L - Users)
# * [ASP 3.4 - Additional Functions]($./ASP 3 - Functions/ASP 3.4 - Additional Functions)

# %% [markdown]
# # Day 3
# ## Functions (Continued)
# * [ASP 3.4L - Abandoned Carts Lab]($./ASP 3 - Functions/ASP 3.4L - Abandoned Carts Lab)
# * [ASP 3.5 - UDFs]($./ASP 3 - Functions/ASP 3.5 - UDFs)
# * [ASP 3.5L - Sort Day Lab]($./ASP 3 - Functions/ASP 3.5L - Sort Day Lab)
#
# ## Performance
# * [ASP 4.1 - Query Optimization]($./ASP 4 - Performance/ASP 4.1 - Query Optimization)
# * [ASP 4.2 - Partitioning]($./ASP 4 - Performance/ASP 4.2 - Partitioning)
# * [ASP 4.2L - De-Duping Data Lab]($./ASP 4 - Performance/ASP 4.2L - De-Duping Data Lab)

# %% [markdown]
# # Day 4
# ## Streaming
# * [ASP 5.1 - Streaming Query]($./ASP 5 - Streaming/ASP 5.1 - Streaming Query)
# * [ASP 5.1aL - Coupon Sales Lab]($./ASP 5 - Streaming/ASP 5.1aL - Coupon Sales Lab)
# * [ASP 5.1bL - Hourly Activity by Traffic Lab]($./ASP 5 - Streaming/ASP 5.1bL - Hourly Activity by Traffic Lab)
# * [ASP 5.1cL - Activity by Traffic Lab]($./ASP 5 - Streaming/ASP 5.1cL - Activity by Traffic Lab)
#
#
# ## Delta Lake
# * [ASP 6.1 - Delta Lake]($./ASP 6 - Delta Lake/ASP 6.1 - Delta Lake)
# * [ASP 6.1L - Delta Lake Lab]($./ASP 6 - Delta Lake/ASP 6.1L - Delta Lake Lab)

# %% [markdown]
# &copy; 2024 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the
# <a href="https://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/><a href="https://databricks.com/privacy-policy">Privacy Policy</a> |
# <a href="https://databricks.com/terms-of-use">Terms of Use</a> |
# <a href="https://help.databricks.com/">Support</a>
