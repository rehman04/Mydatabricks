# %%
import dlt
from pyspark.sql.functions import *

@dlt.table(comment="raw table that contains NYC taxi trips")
@dlt.expect_or_drop("valid_distance", "trip_distance > 0.0")
def taxi_raw_records():
    return spark.readStream.table("samples.nyctaxi.trips")

@dlt.table(comment="total fare amount per week")
def total_fare_amount_by_week():
    return (
        dlt.read("taxi_raw_records")
        .groupBy(date_trunc("week", col("tpep_pickup_datetime")).alias("week"))
        .agg(sum("fare_amount").alias("total_amount"))
    )

@dlt.table(comment="max distance recorded by week")
def max_distance_by_week():
    return (
        dlt.read("taxi_raw_records")
        .groupBy(date_trunc("week", col("tpep_pickup_datetime")).alias("week"))
        .agg(max("trip_distance").alias("max_distance"))
    )
# Out:
# ERROR:py4j.clientserver:There was an exception while executing the Python Proxy on the Python Side.
# Traceback (most recent call last):
#   File "/databricks/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/clientserver.py", line 642, in _call_proxy
#     return_value = getattr(self.pool[obj_id], method)(*params)
#   File "/databricks/spark/python/dlt/helpers.py", line 29, in call
#     res = self.func()
#   File "/root/.ipykernel/4633/command-2255444312437826-2037119577", line 12, in total_fare_amount_by_week
#     dlt.read("taxi_raw_records")
#   File "/databricks/spark/python/dlt/api.py", line 500, in read
#     pipeline.instance.get_scala_pipeline().read(name),
#   File "/databricks/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/java_gateway.py", line 1355, in __call__
#     return_value = get_return_value(
#   File "/databricks/spark/python/pyspark/errors/exceptions/captured.py", line 194, in deco
#     raise converted from None
# pyspark.errors.exceptions.captured.AnalysisException: Failed to read dataset 'taxi_raw_records'. Dataset is not defined in the pipeline.
# ERROR:py4j.clientserver:There was an exception while executing the Python Proxy on the Python Side.
# Traceback (most recent call last):
#   File "/databricks/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/clientserver.py", line 642, in _call_proxy
#     return_value = getattr(self.pool[obj_id], method)(*params)
#   File "/databricks/spark/python/dlt/helpers.py", line 29, in call
#     res = self.func()
#   File "/root/.ipykernel/4633/command-2255444312437826-2037119577", line 20, in max_distance_by_week
#     dlt.read("taxi_raw_records")
#   File "/databricks/spark/python/dlt/api.py", line 500, in read
#     pipeline.instance.get_scala_pipeline().read(name),
#   File "/databricks/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/java_gateway.py", line 1355, in __call__
#     return_value = get_return_value(
#   File "/databricks/spark/python/pyspark/errors/exceptions/captured.py", line 194, in deco
#     raise converted from None
# pyspark.errors.exceptions.captured.AnalysisException: Failed to read dataset 'taxi_raw_records'. Dataset is not defined in the pipeline.
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>max_distance_by_week</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>week</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>max_distance</td>
#    <td>double</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=2459231659607272#joblist/pipelines/create?initialSource=%2FUsers%2Fshifajamali55%40gmail.com%2Fcreate-pipeline-from-sample-data%2Fsample-DLT-pipeline-notebook&redirectNotebookId=2255444312437825">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>
