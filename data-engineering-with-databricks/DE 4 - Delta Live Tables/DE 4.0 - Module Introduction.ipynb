# %% [markdown]
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning">
# </div>

# %% [markdown]
# ## Build Data Pipelines with Delta Live Tables
# This module is part of the Data Engineer Learning Path by Databricks Academy.
#
# #### DLT UI
#
# Lecture: The Medallion Architecture <br>
# Lecture: Introduction to Delta Live Tables <br>
# [DE 4.1 - DLT UI Walkthrough]($./DE 4.1 - DLT UI Walkthrough) <br>
#
# #### DLT Syntax
# DE 4.1.1 - Orders Pipeline: [SQL]($./DE 4.1A - SQL Pipelines/DE 4.1.1 - Orders Pipeline) or [Python]($./DE 4.1B - Python Pipelines/DE 4.1.1 - Orders Pipeline)<br>
# DE 4.1.2 - Customers Pipeline: [SQL]($./DE 4.1A - SQL Pipelines/DE 4.1.2 - Customers Pipeline) or [Python]($./DE 4.1B - Python Pipelines/DE 4.1.2 - Customers Pipeline) <br>
# [DE 4.2 - Python vs SQL]($./DE 4.2 - Python vs SQL) <br>
#
# #### Pipeline Results, Monitoring, and Troubleshooting
# [DE 4.3 - Pipeline Results]($./DE 4.3 - Pipeline Results) <br>
# [DE 4.4 - Pipeline Event Logs]($./DE 4.4 - Pipeline Event Logs) <br>
# DE 4.1.3 - Status Pipeline: [SQL]($./DE 4.1A - SQL Pipelines/DE 4.1.3L - Status Pipeline Lab) or [Python]($./DE 4.1B - Python Pipelines/DE 4.1.3L - Status Pipeline Lab) <br>
# [DE 4.99 - Land New Data]($./DE 4.99 - Land New Data) <br>
#
# #### Prerequisites
#
# * Beginner familiarity with cloud computing concepts (virtual machines, object storage, etc.)
# * Ability to perform basic code development tasks using the Databricks Data Engineering & Data Science workspace (create clusters, run code in notebooks, use basic notebook operations, import repos from Git, etc)
# * Beginning programming experience with Delta Lake
# * Use Delta Lake DDL to create tables, compact files, restore previous table versions, and perform garbage collection of tables in the Lakehouse
#   * Use CTAS to store data derived from a query in a Delta Lake table
#   * Use SQL to perform complete and incremental updates to existing tables
# * Beginning programming experience with Spark SQL or PySpark
#   * Extract data from a variety of file formats and data sources
#   * Apply a number of common transformations to clean data
#   * Reshape and manipulate complex data using advanced built-in functions
# * Production experience working with data warehouses and data lakes

# %% [markdown]
# &copy; 2024 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the
# <a href="https://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/><a href="https://databricks.com/privacy-policy">Privacy Policy</a> |
# <a href="https://databricks.com/terms-of-use">Terms of Use</a> |
# <a href="https://help.databricks.com/">Support</a>
