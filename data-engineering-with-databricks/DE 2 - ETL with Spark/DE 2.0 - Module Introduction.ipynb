# %% [markdown]
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning">
# </div>

# %% [markdown]
# ## Transform Data with Spark
# This module is part of the Data Engineer Learning Path by Databricks Academy, and can be taken in SQL or Python.
#
# #### Extracting Data with Spark
# These notebooks demonstrate Spark SQL concepts relevant to both SQL and PySpark users.
#
# Lecture: Data Objects in the Lakehouse
# [DE 2.1 - Querying Files Directly]($./DE 2.1 - Querying Files Directly)
# [DE 2.2 - Providing Options for External Sources]($./DE 2.2 - Providing Options for External Sources)
# [DE 2.3L - Extract Data Lab]($./DE 2.3L - Extract Data Lab)
#
# #### Transformations for Cleaning Data
# These notebooks include both Spark SQL queries and PySpark DataFrame code side by side to demonstrate the same concepts in both languages.
#
# [DE 2.4 - Cleaning Data]($./DE 2.4 - Cleaning Data)
# [DE 2.5 - Complex Transformations]($./DE 2.5 - Complex Transformations)
# [DE 2.6L - Reshape Data Lab]($./DE 2.6L - Reshape Data Lab)
#
# #### User-Defined Functions
#
# [DE 2.7A - SQL UDFs]($./DE 2.7A - SQL UDFs)
# [DE 2.7B - Python UDFs]($./DE 2.7B - Python UDFs)
# [DE 2.99 - OPTIONAL Higher Order Functions]($./DE 2.99 - OPTIONAL Higher Order Functions)
#
# ### Prerequisites
# Prerequisites for both versions of this course (Spark SQL and PySpark):
# * Beginner familiarity with basic cloud concepts (virtual machines, object storage, identity management)
# * Ability to perform basic code development tasks using the Databricks Data Engineering & Data Science workspace (create clusters, run code in notebooks, use basic notebook operations, import repos from git, etc)
# * Intermediate familiarity with basic SQL concepts (select, filter, groupby, join, etc)
#
# Additional prerequisites for the PySpark version of this course:
# * Beginner programming experience with Python (syntax, conditions, loops, functions)
# * Beginner programming experience with the Spark DataFrame API:
# * Configure DataFrameReader and DataFrameWriter to read and write data
# * Express query transformations using DataFrame methods and Column expressions
# * Navigate the Spark documentation to identify built-in functions for various transformations and data types
#
# Students can take the Introduction to PySpark Programming course from Databricks Academy to learn prerequisite skills for programming with the Spark DataFrame API. <br>

# %% [markdown]
# &copy; 2024 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the
# <a href="https://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/><a href="https://databricks.com/privacy-policy">Privacy Policy</a> |
# <a href="https://databricks.com/terms-of-use">Terms of Use</a> |
# <a href="https://help.databricks.com/">Support</a>
