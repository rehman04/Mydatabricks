# %% [markdown]
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning">
# </div>

# %% [markdown]
# # Develop and Test Pipelines Lab
#
#
#
# ##### Objectives
# - Prepare sample datasets for development environments
# - Define unit tests for ingestion and transformation steps in a DLT pipeline
# - Use temporary DLT tables with expectations to implement unit tests
#
# Generate and trigger an update of a pipeline consisting of the following notebooks:
#
# | Pipeline |
# |---|
# | Bronze / Dev / Ingest Test |
# | Silver / Quarantine |
# | Silver / Users |
# | Silver / Workouts BPM |
# | Tests / Users Test |
# | [Tests / Workouts Test]($./Pipeline/lab/tests/workouts_test) |
#
# Start by running the following setup cell to configure your working environment.

# %%
# %run ./Includes/Classroom-Setup-05.6L

# %% [markdown]
# ## Create Pipeline
# Run the cell below to auto-generate your DLT pipeline using the provided configuration values. Once the pipeline is ready, a link will be provided to navigate you to your auto-generated pipeline in the Pipeline UI.

# %%
DA.generate_pipeline()

# %% [markdown]
# ## Trigger Pipeline Run
# Use the method provided below to trigger a pipeline update.
#
# **IMPORTANT:** You'll need to complete the lab (TODO) in the DLT notebook [workouts_test]($./Pipeline/lab/tests/workouts_test) for this pipeline to run successfully.

# %%
# TODO: Make sure to complete the lab in the DLT notebook linked above (workouts_test) before running this pipeline
DA.start_pipeline()

# %% [markdown]
# &copy; 2024 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the
# <a href="https://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/><a href="https://databricks.com/privacy-policy">Privacy Policy</a> |
# <a href="https://databricks.com/terms-of-use">Terms of Use</a> |
# <a href="https://help.databricks.com/">Support</a>
