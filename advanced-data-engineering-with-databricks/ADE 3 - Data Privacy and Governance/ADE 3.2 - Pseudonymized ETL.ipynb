# %% [markdown]
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning">
# </div>

# %% [markdown]
# # Pseudonymized ETL
#
# This notebook allows you to programmatically:
#
# * Generate the DLT pipeline
# * Trigger a pipeline run
# * Explore the resultant DAG
# * Land a new batch of data
#
# ## The Pipeline
# The pipeline we are using in this lesson is located [here]($./Pipeline/ADE 3.1.2 - Pseudonymized ETL).

# %% [markdown]
# Run the following cell to configure your working environment for this course.

# %%
# %run ./Includes/Classroom-Setup-03.2
# Out:
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Resetting the learning environment (pii):
# | removing the working directory "dbfs:/mnt/dbacademy-users/shifajamali55@gmail.com/advanced-data-engineering-with-databricks/pii"...(1 seconds)
#
# Skipping install of existing datasets to "dbfs:/mnt/dbacademy-datasets/data-engineer-learning-path/v04"
#
# Validating the locally installed datasets:
# | listing local files...(6 seconds)
# | validation completed...(6 seconds total)
#
# Creating & using the schema "shifajamali55_soeb_da_adewd_pii" in the catalog "hive_metastore"...(1 seconds)
# Cloning the "shifajamali55_soeb_da_adewd_pii_lookup.date_lookup" table from "dbfs:/mnt/dbacademy-datasets/data-engineer-learning-path/v04/date-lookup"....(18 seconds)
# Cloning the "shifajamali55_soeb_da_adewd_pii_lookup.user_lookup" table from "dbfs:/mnt/dbacademy-datasets/data-engineer-learning-path/v04/user-lookup"....(13 seconds)
# ** WARNING: POLICY NOT FOUND ***********************************************************************
# * Could not find the cluster policy "DBAcademy DLT".
# * Please run the notebook Includes/Workspace-Setup to address this error.
# ****************************************************************************************************
#
# Loading all batches to the stream...Loaded 100 records
# Loading batch #1 to the stream...Loaded 417,276 records
#
# Predefined tables in "shifajamali55_soeb_da_adewd_pii":
# | registered_users
# | user_lookup
#
# Predefined paths variables:
# | DA.paths.working_dir:      dbfs:/mnt/dbacademy-users/shifajamali55@gmail.com/advanced-data-engineering-with-databricks/pii
# | DA.paths.user_db:          dbfs:/mnt/dbacademy-users/shifajamali55@gmail.com/advanced-data-engineering-with-databricks/pii/database.db
# | DA.paths.datasets:         dbfs:/mnt/dbacademy-datasets/data-engineer-learning-path/v04
# | DA.paths.stream_source:    dbfs:/mnt/dbacademy-users/shifajamali55@gmail.com/advanced-data-engineering-with-databricks/pii/stream_source
# | DA.paths.storage_location: dbfs:/mnt/dbacademy-users/shifajamali55@gmail.com/advanced-data-engineering-with-databricks/pii/storage_location
#
# Setup completed (62 seconds)

# %% [markdown]
# ## Generate DLT Pipeline
# Run the cell below to auto-generate your DLT pipeline using the provided configuration values.
#
# Once the pipeline is ready, a link will be provided to navigate you to your auto-generated pipeline in the Pipeline UI.

# %%
DA.generate_pipeline()
# Out:
# <table style="width:100%">
#         <tr>
#             <td style="white-space:nowrap; width:1em">Pipeline Name:</td>
#             <td><input type="text" value="shifajamali55-soeb-da-adewd-pii: Pipeline - pii" style="width: 100%"></td></tr>
#         <tr>
#             <td style="white-space:nowrap; width:1em">Storage Location:</td>
#             <td><input type="text" value="dbfs:/mnt/dbacademy-users/shifajamali55@gmail.com/advanced-data-engineering-with-databricks/pii/storage_location" style="width: 100%"></td></tr>
#         <tr>
#             <td style="white-space:nowrap; width:1em">Target:</td>
#             <td><input type="text" value="shifajamali55_soeb_da_adewd_pii" style="width: 100%"></td></tr>
#         <tr>
#             <td style="white-space:nowrap; width:1em">Policy:</td>
#             <td><input type="text" value="None" style="width: 100%"></td></tr>
#         <tr>
#             <td style="white-space:nowrap; width:1em">source:</td>
#             <td><input type="text" value="dbfs:/mnt/dbacademy-users/shifajamali55@gmail.com/advanced-data-engineering-with-databricks/pii/stream_source" style="width: 100%"></td></tr>
#         <tr>
#             <td style="white-space:nowrap; width:1em">lookup_db:</td>
#             <td><input type="text" value="shifajamali55_soeb_da_adewd_pii_lookup" style="width: 100%"></td></tr>
#         <tr>
#             <td style="white-space:nowrap; width:1em">Notebook #1 Path:</td>
#             <td><input type="text" value="/Users/shifajamali55@gmail.com/advanced-data-engineering-with-databricks/ADE 3 - Data Privacy and Governance/Pipeline/ADE 3.1.1 - PII Lookup Table" style="width: 100%"></td></tr>
#         <tr>
#             <td style="white-space:nowrap; width:1em">Notebook #2 Path:</td>
#             <td><input type="text" value="/Users/shifajamali55@gmail.com/advanced-data-engineering-with-databricks/ADE 3 - Data Privacy and Governance/Pipeline/ADE 3.1.2 - Pseudonymized ETL" style="width: 100%"></td></tr></table>
# Created the pipeline "shifajamali55-soeb-da-adewd-pii: Pipeline - pii": <a href=https://dbc-f450058a-abb8.cloud.databricks.com/?o=2459231659607272#joblist/pipelines/2b63156c-82ff-40c9-a558-edf3f24eebac>2b63156c-82ff-40c9-a558-edf3f24eebac</a>
# '2b63156c-82ff-40c9-a558-edf3f24eebac'

# %% [markdown]
# ## Trigger Pipeline Run
#
# With a pipeline created, you will now run the pipeline. The initial run will take several minutes while a cluster is provisioned. Subsequent runs will be appreciably quicker.
#
# Explore the DAG - As the pipeline completes, the execution flow is graphed. With each triggered update, all newly arriving data will be processed through your pipeline. Metrics will always be reported for current run.

# %%
DA.start_pipeline()
# Out:
# Current state is CREATED, sleeping 15 seconds.
# Current state is WAITING_FOR_RESOURCES, sleeping 15 seconds.
# Current state is WAITING_FOR_RESOURCES, sleeping 15 seconds.
# Current state is WAITING_FOR_RESOURCES, sleeping 15 seconds.
# Current state is WAITING_FOR_RESOURCES, sleeping 15 seconds.
# Current state is WAITING_FOR_RESOURCES, sleeping 15 seconds.
# Current state is WAITING_FOR_RESOURCES, sleeping 15 seconds.
# Current state is WAITING_FOR_RESOURCES, sleeping 15 seconds.
# Current state is WAITING_FOR_RESOURCES, sleeping 15 seconds.
# Current state is WAITING_FOR_RESOURCES, sleeping 15 seconds.
# Current state is WAITING_FOR_RESOURCES, sleeping 15 seconds.
# Current state is WAITING_FOR_RESOURCES, sleeping 15 seconds.
# Current state is WAITING_FOR_RESOURCES, sleeping 15 seconds.
# Current state is WAITING_FOR_RESOURCES, sleeping 15 seconds.
# Current state is WAITING_FOR_RESOURCES, sleeping 15 seconds.
# Current state is WAITING_FOR_RESOURCES, sleeping 15 seconds.
# Current state is WAITING_FOR_RESOURCES, sleeping 15 seconds.
# Current state is INITIALIZING, sleeping 15 seconds.
# Current state is SETTING_UP_TABLES, sleeping 15 seconds.
# Current state is SETTING_UP_TABLES, sleeping 15 seconds.
# Current state is RUNNING, sleeping 15 seconds.
# Current state is RUNNING, sleeping 15 seconds.
# The final state is COMPLETED.
# '4fbeaee7-d9fb-40e9-a138-cb8efdb7cc85'

# %% [markdown]
# ## Land New Data
#
# Run the cell below to land more data in the source directory, then manually trigger a pipeline update.
#
# As we continue through the course, you can return to this notebook and use the method provided below to land new data. Running this entire notebook again will delete the underlying data files for both the source data and your DLT Pipeline.

# %%
DA.daily_stream.load()
# Out:
# Loading batch #2 to the stream...Loaded 462,415 records

# %% [markdown]
# ## Process All Remaining Data
# To continuously load all remaining batches of data to the source directory, call the same load method above with the **`continuous`** parameter set to **`True`**.
#
# Trigger another update to process the remaining data.

# %%
DA.daily_stream.load(continuous=True)  # Load all remaining batches of data
DA.start_pipeline()  # Trigger another pipeline update
# Out:
# Loading all batches to the stream...Loaded 9,962,287 records
# Current state is CREATED, sleeping 15 seconds.
# Current state is SETTING_UP_TABLES, sleeping 15 seconds.
# Current state is RUNNING, sleeping 15 seconds.
# Current state is RUNNING, sleeping 15 seconds.
# Current state is RUNNING, sleeping 15 seconds.
# The final state is COMPLETED.
# '2158e722-e4b1-40e1-9333-63ebdcd2cbff'

# %% [markdown]
# &copy; 2024 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the
# <a href="https://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/><a href="https://databricks.com/privacy-policy">Privacy Policy</a> |
# <a href="https://databricks.com/terms-of-use">Terms of Use</a> |
# <a href="https://help.databricks.com/">Support</a>
