# %% [markdown]
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning">
# </div>

# %% [markdown]
# # Using the Delta Live Tables UI
#
# This demo will explore the DLT UI. By the end of this lesson you will be able to:
#
# * Deploy a DLT pipeline
# * Explore the resultant DAG
# * Execute an update of the pipeline

# %% [markdown]
# ## Classroom Setup
#
# Run the following cell to configure your working environment for this course.

# %%
# %run ./Includes/Classroom-Setup-04.1

# %% [markdown]
# ## Validate the Pipeline Configuration
#
# 1. In the Databricks workspace, open the Delta Live Tables (DLT) UI.
#
# 2. Select your pipeline configuration.
#
# 3. Review the pipeline configuration settings to ensure they are correctly configured according to the provided instructions.
#
# 4. **Important:** Remove the maintenance cluster if it is currently part of your pipeline configuration. This is required to successfully validate the pipeline configuration.
#
# 5. Once you've confirmed that the pipeline configuration is set up correctly and the maintenance cluster has been removed, proceed to the next steps for validating and running the pipeline.

# %% [markdown]
# ## Generate Pipeline Configuration
# Configuring this pipeline will require parameters unique to a given user.
#
# In the code cell below, specify which language to use by uncommenting the appropriate line.
#
# Then, run the cell to print out values you'll use to configure your pipeline in subsequent steps.

# %%
pipeline_language = "SQL"
#pipeline_language = "Python"

DA.print_pipeline_config(pipeline_language)

# %% [markdown]
# In this lesson, we deploy a pipeline with a single notebook, specified as Notebook #1 in the cell output above.
#
# <img src="https://files.training.databricks.com/images/icon_hint_24.png"> **HINT:**  You'll want to refer back to the paths above when we add Notebook #2 and #3 to the pipeline in later lessons.

# %% [markdown]
# ## Create and Configure a Pipeline
#
# Let's start by creating a pipeline with a single notebook (Notebook #1).
#
# Steps:
# 1. Click the **Workflows** button on the sidebar, click the **Delta Live Tables** tab, and click **Create Pipeline**.
# 2. Configure the pipeline as specified below. You'll need the values provided in the cell output above for this step.
#
# | Setting | Instructions |
# |--|--|
# | Pipeline name | Enter the **Pipeline Name** provided above |
# | Product edition | Choose **Advanced** |
# | Pipeline mode | Choose **Triggered** |
# | Paths | Use the navigator to select or enter the **Notebook # 1 Path** provided above |
# | Storage location | Enter the **Storage Location** provided above |
# | Target schema | Enter the **Target** database name provided above |
# | Cluster policy | Choose the **Policy** provided above |
# | Cluster mode | Choose **Fixed size** to disable auto scaling for your cluster |
# | Workers | Enter **0** to use a Single Node cluster |
# | Photon Acceleration | Check this checkbox to enable |
# | Advanced | Click **Add Configuration** to input the **Key** and **Value** for row #1 in the table below,<br>Click **Add Configuration** to input the **Key** and **Value** for row #2 in the table below |
# | Channel | Choose **Current** to use the current runtime version |
#
# | Configuration | Key                 | Value                                      |
# | ------------- | ------------------- | ------------------------------------------ |
# | #1            | **`spark.master`**  | **`local[*]`**                             |
# | #2            | **`source`** | Enter the **source** provided above |
#
# <br>
#
# 3. Click the **Create** button.
# 4. Verify that the pipeline mode is set to **Development**.

# %%
# This function is provided for students who do not 
# want to work through the exercise of creating the pipeline.
DA.create_pipeline(pipeline_language)

# %%
DA.validate_pipeline_config(pipeline_language)

# %% [markdown]
# #### Additional Notes on Pipeline Configuration
# Here are a few notes regarding the pipeline settings above:
#
# - **Pipeline mode** - This specifies how the pipeline will be run. Choose the mode based on latency and cost requirements.
#   - `Triggered` pipelines run once and then shut down until the next manual or scheduled update.
#   - `Continuous` pipelines run continuously, ingesting new data as it arrives.
# - **Notebook libraries** - Even though this document is a standard Databricks Notebook, the SQL syntax is specialized to DLT table declarations. We will be exploring the syntax in the exercise that follows.
# - **Storage location** - This optional field allows the user to specify a location to store logs, tables, and other information related to pipeline execution. If not specified, DLT will automatically generate a directory.
# - **Target** - If this optional field is not specified, tables will not be registered to a metastore, but will still be available in the DBFS. See <a href="https://docs.databricks.com/data-engineering/delta-live-tables/delta-live-tables-user-guide.html#publish-tables" target="_blank">documentation</a> for more information on this option.
# - **Cluster mode**, **Min Workers**, **Max Workers** - These fields control the worker configuration for the underlying cluster processing the pipeline. Here, we set the number of workers to 0. This works in conjunction with the **spark.master** parameter defined above to configure the cluster as a Single Node cluster.
# - **source** - These keys are caps sensitive. Make sure you've got all lower case letters for the word "source"!

# %% [markdown]
# ## Run a Pipeline
#
# With a pipeline created, you will now run the pipeline.
#
# 1. Select **Development** to run the pipeline in development mode. Development mode provides for more expeditious iterative development by reusing the cluster (as opposed to creating a new cluster for each run) and disabling retries so that you can readily identify and fix errors. Refer to the <a href="https://docs.databricks.com/data-engineering/delta-live-tables/delta-live-tables-user-guide.html#optimize-execution" target="_blank">documentation</a> for more information on this feature.
# 2. Click **Start**.
#
# The initial run will take several minutes while a cluster is provisioned. Subsequent runs will be appreciably quicker.
#
# **Note:** If you have created the DLT pipeline manually as described in a previous step, you do not need to run the `DA.start_pipeline()` script. Running this script may not apply to your scenario and could lead to confusion.

# %% [markdown]
# ## What is Full Refresh?

# %%
# This function is provided to start the pipeline and  
# block until it has completed, canceled or failed
DA.start_pipeline()

# %% [markdown]
# ## Explore the DAG
#
# As the pipeline completes, the execution flow is graphed.
#
# Selecting the tables reviews the details.
#
# Select **orders_silver**. Notice the results reported in the **Data Quality** section.
#
# With each triggered update, all newly arriving data will be processed through your pipeline. Metrics will always be reported for current run.

# %% [markdown]
# ## Land another batch of data
#
# Run the cell below to land more data in the source directory, then manually trigger a pipeline update.

# %% [markdown]
# ### Next Steps
#
# Congratulations on completing the UI walkthrough in section 4.1! Now, here's what to do next:
#
# 1. **Review Notebook 1:** Navigate to Notebook 1, where you'll find additional exercises and hands-on activities related to the topics covered in the UI walkthrough.
#
# 2. **Review Notebook 2:** Move on to Notebook 2, which further expands on the concepts learned in the previous notebooks.
#
# 3. **Troubleshoot in Notebook 3:** If you encounter any issues or want to delve deeper into problem-solving, proceed to Notebook 3 for troubleshooting guidance.
#
# 4. **Finally, 4.2:** Once you've gone through the previous notebooks, you'll be well-prepared to tackle the content in section 4.2.
#
# Take your time, and feel free to revisit any section as needed to solidify your understanding. **Happy learning!**

# %%
DA.dlt_data_factory.load()

# %% [markdown]
# As we continue through the course, you can return to this notebook and use the method provided above to land new data.
#
# Running this entire notebook again will delete the underlying data files for both the source data and your DLT Pipeline.
#
# If you get disconnected from your cluster or have some other event where you wish to land more data without deleting things, refer to the <a href="$./DE 4.99 - Land New Data" target="_blank">DE 4.99 - Land New Data</a> notebook.

# %% [markdown]
# &copy; 2024 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the
# <a href="https://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/><a href="https://databricks.com/privacy-policy">Privacy Policy</a> |
# <a href="https://databricks.com/terms-of-use">Terms of Use</a> |
# <a href="https://help.databricks.com/">Support</a>
