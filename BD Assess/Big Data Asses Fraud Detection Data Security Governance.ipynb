# %%
# %sql
USE CATALOG asscom1fraudanalysis;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# Creating User Groups For Access Control List

# %%
# %sql
CREATE GROUP analysts WITH USER  `shifajamali55@gmail.com`;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
CREATE GROUP dataengineers WITH USER  `shifajamali55@gmail.com`;

# %%
# %sql

SHOW GROUPS;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th><th>directGroup</th></tr></thead><tbody><tr><td>analysts</td><td>null</td></tr><tr><td>users</td><td>null</td></tr><tr><td>dataengineers</td><td>null</td></tr><tr><td>admins</td><td>null</td></tr></tbody></table></div>

# %% [markdown]
# Granting Access to different user groups

# %%
# %sql
-- - Grant SELECT permission to the 'analysts' group
GRANT SELECT ON TABLE asscom1fraudanalysis.bdcom1asses.gold_transactions TO analysts;
-- Grant SELECT and MODIFY permissions to the 'dataengineers' group
GRANT SELECT, MODIFY ON SCHEMA asscom1fraudanalysis.bdcom1asses TO `dataengineers`;

# %%
# %sql

GRANT ALL PRIVILEGES ON TABLE asscom1fraudanalysis.bdcom1asses.gold_transactions 
TO `shifajamali55@gmail.com`
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
